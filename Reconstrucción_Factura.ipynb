# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.firefox.options import Options
import time, json
from webdriver_manager.firefox import GeckoDriverManager
import os
import sys
from selenium.webdriver.common.by import By
import pandas as pd
from tkinter import messagebox



os.path.dirname(sys.executable)

from time import sleep 
from selenium import webdriver
# esto se prueba en Firefox o puede usar el navegador "webdriver.Chrome()" 
browser = webdriver.Firefox(executable_path=r'C:\Users\yazie\OneDrive\Documentos\PYTHON\Altas-Empleados\geckodriver.exe')
browser.get('http://www.eraindefleet.com/TPB')

#DATOS LOG IN
user= 'YBARBOSA'
psw= 'Ybarbosa_22'


usuario= browser.find_element(By.XPATH, '//*[@id="usuario"]')
usuario.send_keys(user)
contraseña= browser.find_element(By.XPATH,'//*[@id="contrasena"]')
contraseña.send_keys(psw)

click_login= browser.find_element(By.XPATH,'//*[@id="Button1"]')
click_login.click()

#Entramos a menú
click_cxc= browser.find_element(By.XPATH,'/html/body/form/div[5]/div/ul/li[5]/a')
click_cxc.click()
sleep(3)
#Boton Desplegable
click_facturar=browser.find_element(By.XPATH,'/html/body/form/div[6]/div/div[2]/ul[4]/li/a')
click_facturar.click()
sleep(3)

#Boton de descarga de facturas
click_ReporteFac=browser.find_element(By.XPATH,'/html/body/form/div[6]/div/div[2]/ul[4]/li/ul/li[3]/a[2]')
click_ReporteFac.click()
#fecha_a='08/08/2022'
fecha_a=str(input("Fecha inicio: "))
#fecha_b='09/08/2022'
fecha_b=str(input("Fecha final: "))
#cliente_RFac='ONE OCEAN'
cliente_RFac=str(input("Cliente: "))
fecha_a_ReporteFac=browser.find_element(By.XPATH,'//*[@id="FFechaini"]')
fecha_b_ReporteFac=browser.find_element(By.XPATH,'//*[@id="FFechafin"]')
cliente_ReporteFac=browser.find_element(By.XPATH,'//*[@id="FCliente"]')
fecha_a_ReporteFac.send_keys(fecha_a)
fecha_b_ReporteFac.send_keys(fecha_b)
cliente_ReporteFac.send_keys(cliente_RFac)
click_mostrar_ReporteFac=browser.find_element(By.XPATH,'//*[@id="btnBuscar"]')
click_mostrar_ReporteFac.click()

#Descarga de FACTURAS
#PROCESO RARO
sleep(10)
amen=browser.find_element_by_id('PDF').get_attribute('href')
amen_txt=browser.find_element_by_id('PDF')
#continue_link = browser.find_element(By.PARTIAL_LINK_TEXT,'./ArchivoNotaDeCreditoPDF')
print( amen )
print(amen_txt)
#elem = browser.find_elements(By.XPATH,"//*[@href]")
anose=browser.find_elements_by_id('PDF')
tag_list=browser.find_element(By.TAG_NAME, 'a')
print(tag_list)
#elem.split()
#print(elem)
#print(anose)
for m in anose:
    m.location_once_scrolled_into_view
    fuego=m.get_attribute('href')
    id_str=fuego[64:69]
    id_je=browser.find_element(By.XPATH,'//*[@id="lnkId"]')
    id_je.click()
    reconstruir_button= browser.find_element(By.XPATH,'//*[@id="btnReconstruirPDF"]')
    #elem = browser.find_element(By.XPATH,'//*[@id="PDF"]')
    #elem.click()



messagebox.showinfo(message="DESCARGA DE FACTURAS TERMINADA", title="ESTATUS DE PROCESO(1)")


    #print(len(fuego))
    
#Extraemos desde un excel
#archivo=str(input('Ingrese a ruta del libro de Excel: ')) 
#sheet_name = 0 
#header = 0 # The header is the 2nd row
#df=pd.read_excel(r'C:\Users\yazie\Downloads\HENCO-FACTURAS A DESCARGAR.xlsx',engine='openpyxl',sheet_name=0,header=0)

#LISTA=df.to_numpy().transpose().tolist()
#print(LISTA)
#for a in LISTA:
#    href_text='./ArchivoNotaDeCreditoPDF.ashx?ID='+a



#http://www.eraindefleet.com/TPB/ArchivoNotaDeCreditoPDF.ashx?ID=90209
#rows.click()
#sleep(10)
#for row in rows:
#    print(rows)

#//*[@id="PDF"]
#html body form#Form1 center table tbody tr td center div#divListado div table#GvPrefacturas.tabla_pick.vertical tbody tr td a#PDF img
##GvPrefacturas > tbody:nth-child(1) > tr:nth-child(11) > td:nth-child(13) > a:nth-child(1) > img:nth-child(1)
#href

#/html/body/form/center/table/tbody/tr/td/center/div/div/table/tbody/tr[11]/td[13]/a/img
#/html/body/form/center/table/tbody/tr/td/center/div/div/table/tbody/tr[14]/td[13]/a/img
#Boton Reporte de Cartas Porte
#click_Report_CP=browser.find_element(By.XPATH,'/html/body/form/div[6]/div/div[2]/ul[4]/li/ul/li[8]/a')
#click_Report_CP.click()
#sleep(3)
#sleep(8)
#browser.close()
